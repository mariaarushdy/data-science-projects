# %%
#readxl reads xl file
library(readxl)
cars <- read_excel("Advanced cars.xlsx")
cars
# Out:
#       Make    Model      Year FuelType                       HP  Cylinders
# 1     BMW     1 Series M 2011 premium unleaded (required)    335 6
# 2     BMW     1 Series   2011 premium unleaded (required)    300 6
# 3     BMW     1 Series   2011 premium unleaded (required)    300 6
# 4     BMW     1 Series   2011 premium unleaded (required)    230 6
# 5     BMW     1 Series   2011 premium unleaded (required)    230 6
# 6     BMW     1 Series   2012 premium unleaded (required)    230 6
# 7     BMW     1 Series   2012 premium unleaded (required)    300 6
# 8     BMW     1 Series   2012 premium unleaded (required)    300 6
# 9     BMW     1 Series   2012 premium unleaded (required)    230 6
# 10    BMW     1 Series   2013 premium unleaded (required)    230 6
# 11    BMW     1 Series   2013 premium unleaded (required)    300 6
# 12    BMW     1 Series   2013 premium unleaded (required)    230 6
# 13    BMW     1 Series   2013 premium unleaded (required)    300 6
# 14    BMW     1 Series   2013 premium unleaded (required)    230 6
# 15    BMW     1 Series   2013 premium unleaded (required)    230 6
# 16    BMW     1 Series   2013 premium unleaded (required)    320 6
# 17    BMW     1 Series   2013 premium unleaded (required)    320 6
# 18    Audi    100        1992 regular unleaded               172 6
# 19    Audi    100        1992 regular unleaded               172 6
# 20    Audi    100        1992 regular unleaded               172 6
# 21    Audi    100        1992 regular unleaded               172 6
# 22    Audi    100        1992 regular unleaded               172 6
# 23    Audi    100        1993 regular unleaded               172 6
# 24    Audi    100        1993 regular unleaded               172 6
# 25    Audi    100        1993 regular unleaded               172 6
# 26    Audi    100        1993 regular unleaded               172 6
# 27    Audi    100        1993 regular unleaded               172 6
# 28    Audi    100        1994 regular unleaded               172 6
# 29    Audi    100        1994 regular unleaded               172 6
# 30    Audi    100        1994 regular unleaded               172 6
# ...   ...     ...        ...  ...                            ... ...
# 11885 BMW     Z3         2001 premium unleaded (required)    225 6
# 11886 BMW     Z3         2001 premium unleaded (required)    184 6
# 11887 BMW     Z3         2001 premium unleaded (required)    225 6
# 11888 BMW     Z3         2002 premium unleaded (required)    225 6
# 11889 BMW     Z3         2002 premium unleaded (required)    184 6
# 11890 BMW     Z3         2002 premium unleaded (required)    225 6
# 11891 BMW     Z4 M       2007 premium unleaded (required)    330 6
# 11892 BMW     Z4 M       2007 premium unleaded (required)    330 6
# 11893 BMW     Z4 M       2008 premium unleaded (required)    330 6
# 11894 BMW     Z4 M       2008 premium unleaded (required)    330 6
# 11895 BMW     Z4         2014 premium unleaded (required)    240 4
# 11896 BMW     Z4         2014 premium unleaded (required)    300 6
# 11897 BMW     Z4         2014 premium unleaded (required)    335 6
# 11898 BMW     Z4         2015 premium unleaded (required)    240 4
# 11899 BMW     Z4         2015 premium unleaded (required)    300 6
# 11900 BMW     Z4         2015 premium unleaded (required)    335 6
# 11901 BMW     Z4         2016 premium unleaded (required)    300 6
# 11902 BMW     Z4         2016 premium unleaded (required)    240 4
# 11903 BMW     Z4         2016 premium unleaded (required)    335 6
# 11904 BMW     Z8         2001 premium unleaded (required)    394 8
# 11905 BMW     Z8         2002 premium unleaded (required)    394 8
# 11906 BMW     Z8         2003 premium unleaded (required)    394 8
# 11907 Acura   ZDX        2011 premium unleaded (required)    300 6
# 11908 Acura   ZDX        2011 premium unleaded (required)    300 6
# 11909 Acura   ZDX        2011 premium unleaded (required)    300 6
# 11910 Acura   ZDX        2012 premium unleaded (required)    300 6
# 11911 Acura   ZDX        2012 premium unleaded (required)    300 6
# 11912 Acura   ZDX        2012 premium unleaded (required)    300 6
# 11913 Acura   ZDX        2013 premium unleaded (recommended) 300 6
# 11914 Lincoln Zephyr     2006 regular unleaded               221 6
#       TransmissionType Driven_Wheels     NumberofDoors
# 1     MANUAL           rear wheel drive  2
# 2     MANUAL           rear wheel drive  2
# 3     MANUAL           rear wheel drive  2
# 4     MANUAL           rear wheel drive  2
# 5     MANUAL           rear wheel drive  2
# 6     MANUAL           rear wheel drive  2
# 7     MANUAL           rear wheel drive  2
# 8     MANUAL           rear wheel drive  2
# 9     MANUAL           rear wheel drive  2
# 10    MANUAL           rear wheel drive  2
# 11    MANUAL           rear wheel drive  2
# 12    MANUAL           rear wheel drive  2
# 13    MANUAL           rear wheel drive  2
# 14    MANUAL           rear wheel drive  2
# 15    MANUAL           rear wheel drive  2
# 16    MANUAL           rear wheel drive  2
# 17    MANUAL           rear wheel drive  2
# 18    MANUAL           front wheel drive 4
# 19    MANUAL           front wheel drive 4
# 20    AUTOMATIC        all wheel drive   4
# 21    MANUAL           front wheel drive 4
# 22    MANUAL           all wheel drive   4
# 23    MANUAL           front wheel drive 4
# 24    AUTOMATIC        all wheel drive   4
# 25    MANUAL           front wheel drive 4
# 26    MANUAL           front wheel drive 4
# 27    MANUAL           all wheel drive   4
# 28    AUTOMATIC        front wheel drive 4
# 29    MANUAL           all wheel drive   4
# 30    MANUAL           front wheel drive 4
# ...   ...              ...               ...
# 11885 MANUAL           rear wheel drive  2
# 11886 MANUAL           rear wheel drive  2
# 11887 MANUAL           rear wheel drive  2
# 11888 MANUAL           rear wheel drive  2
# 11889 MANUAL           rear wheel drive  2
# 11890 MANUAL           rear wheel drive  2
# 11891 MANUAL           rear wheel drive  2
# 11892 MANUAL           rear wheel drive  2
# 11893 MANUAL           rear wheel drive  2
# 11894 MANUAL           rear wheel drive  2
# 11895 MANUAL           rear wheel drive  2
# 11896 MANUAL           rear wheel drive  2
# 11897 AUTOMATED_MANUAL rear wheel drive  2
# 11898 MANUAL           rear wheel drive  2
# 11899 AUTOMATED_MANUAL rear wheel drive  2
# 11900 AUTOMATED_MANUAL rear wheel drive  2
# 11901 AUTOMATED_MANUAL rear wheel drive  2
# 11902 MANUAL           rear wheel drive  2
# 11903 AUTOMATED_MANUAL rear wheel drive  2
# 11904 MANUAL           rear wheel drive  2
# 11905 MANUAL           rear wheel drive  2
# 11906 MANUAL           rear wheel drive  2
# 11907 AUTOMATIC        all wheel drive   4
# 11908 AUTOMATIC        all wheel drive   4
# 11909 AUTOMATIC        all wheel drive   4
# 11910 AUTOMATIC        all wheel drive   4
# 11911 AUTOMATIC        all wheel drive   4
# 11912 AUTOMATIC        all wheel drive   4
# 11913 AUTOMATIC        all wheel drive   4
# 11914 AUTOMATIC        front wheel drive 4
#       MarketCategory                        VehicleSize VehicleStyle
# 1     Factory Tuner,Luxury,High-Performance Compact     Coupe
# 2     Luxury,Performance                    Compact     Convertible
# 3     Luxury,High-Performance               Compact     Coupe
# 4     Luxury,Performance                    Compact     Coupe
# 5     Luxury                                Compact     Convertible
# 6     Luxury,Performance                    Compact     Coupe
# 7     Luxury,Performance                    Compact     Convertible
# 8     Luxury,High-Performance               Compact     Coupe
# 9     Luxury                                Compact     Convertible
# 10    Luxury                                Compact     Convertible
# 11    Luxury,High-Performance               Compact     Coupe
# 12    Luxury,Performance                    Compact     Coupe
# 13    Luxury,Performance                    Compact     Convertible
# 14    Luxury                                Compact     Convertible
# 15    Luxury,Performance                    Compact     Coupe
# 16    Luxury,High-Performance               Compact     Convertible
# 17    Luxury,High-Performance               Compact     Coupe
# 18    Luxury                                Midsize     Sedan
# 19    Luxury                                Midsize     Sedan
# 20    Luxury                                Midsize     Wagon
# 21    Luxury                                Midsize     Sedan
# 22    Luxury                                Midsize     Sedan
# 23    Luxury                                Midsize     Sedan
# 24    Luxury                                Midsize     Wagon
# 25    Luxury                                Midsize     Sedan
# 26    Luxury                                Midsize     Sedan
# 27    Luxury                                Midsize     Sedan
# 28    Luxury                                Midsize     Wagon
# 29    Luxury                                Midsize     Sedan
# 30    Luxury                                Midsize     Sedan
# ...   ...                                   ...         ...
# 11885 Luxury,Performance                    Compact     Convertible
# 11886 Luxury,Performance                    Compact     Convertible
# 11887 Hatchback,Luxury,Performance          Compact     2dr Hatchback
# 11888 Luxury,Performance                    Compact     Convertible
# 11889 Luxury,Performance                    Compact     Convertible
# 11890 Hatchback,Luxury,Performance          Compact     2dr Hatchback
# 11891 Factory Tuner,Luxury,High-Performance Compact     Coupe
# 11892 Factory Tuner,Luxury,High-Performance Compact     Convertible
# 11893 Factory Tuner,Luxury,High-Performance Compact     Coupe
# 11894 Factory Tuner,Luxury,High-Performance Compact     Convertible
# 11895 Luxury,Performance                    Compact     Convertible
# 11896 Luxury,High-Performance               Compact     Convertible
# 11897 Luxury,High-Performance               Compact     Convertible
# 11898 Luxury,Performance                    Compact     Convertible
# 11899 Luxury,High-Performance               Compact     Convertible
# 11900 Luxury,High-Performance               Compact     Convertible
# 11901 Luxury,High-Performance               Compact     Convertible
# 11902 Luxury,Performance                    Compact     Convertible
# 11903 Luxury,High-Performance               Compact     Convertible
# 11904 Exotic,Luxury,High-Performance        Compact     Convertible
# 11905 Exotic,Luxury,High-Performance        Compact     Convertible
# 11906 Exotic,Luxury,High-Performance        Compact     Convertible
# 11907 Crossover,Hatchback,Luxury            Midsize     4dr Hatchback
# 11908 Crossover,Hatchback,Luxury            Midsize     4dr Hatchback
# 11909 Crossover,Hatchback,Luxury            Midsize     4dr Hatchback
# 11910 Crossover,Hatchback,Luxury            Midsize     4dr Hatchback
# 11911 Crossover,Hatchback,Luxury            Midsize     4dr Hatchback
# 11912 Crossover,Hatchback,Luxury            Midsize     4dr Hatchback
# 11913 Crossover,Hatchback,Luxury            Midsize     4dr Hatchback
# 11914 Luxury                                Midsize     Sedan
#       highwayMPG citympg Popularity MSRP
# 1     26         19      3916       46135
# 2     28         19      3916       40650
# 3     28         20      3916       36350
# 4     28         18      3916       29450
# 5     28         18      3916       34500
# 6     28         18      3916       31200
# 7     26         17      3916       44100
# 8     28         20      3916       39300
# 9     28         18      3916       36900
# 10    27         18      3916       37200
# 11    28         20      3916       39600
# 12    28         19      3916       31500
# 13    28         19      3916       44400
# 14    28         19      3916       37200
# 15    28         19      3916       31500
# 16    25         18      3916       48250
# 17    28         20      3916       43550
# 18    24         17      3105        2000
# 19    24         17      3105        2000
# 20    20         16      3105        2000
# 21    24         17      3105        2000
# 22    21         16      3105        2000
# 23    24         17      3105        2000
# 24    20         16      3105        2000
# 25    24         17      3105        2000
# 26    24         17      3105        2000
# 27    21         16      3105        2000
# 28    21         16      3105        2000
# 29    22         16      3105        2000
# 30    22         17      3105        2000
# ...   ...        ...     ...        ...
# 11885 26         19      3916        37900
# 11886 25         18      3916        31300
# 11887 26         19      3916        37700
# 11888 26         19      3916        37900
# 11889 25         18      3916        31300
# 11890 26         19      3916        37700
# 11891 22         15      3916        50100
# 11892 22         15      3916        52100
# 11893 23         15      3916        50400
# 11894 23         15      3916        52400
# 11895 34         22      3916        48950
# 11896 26         19      3916        56950
# 11897 24         17      3916        65800
# 11898 34         22      3916        48950
# 11899 24         17      3916        56950
# 11900 24         17      3916        65800
# 11901 24         17      3916        57500
# 11902 34         22      3916        49700
# 11903 24         17      3916        66350
# 11904 19         12      3916       128000
# 11905 19         12      3916       130000
# 11906 19         12      3916       131500
# 11907 23         16       204        46020
# 11908 23         16       204        56570
# 11909 23         16       204        50520
# 11910 23         16       204        46120
# 11911 23         16       204        56670
# 11912 23         16       204        50620
# 11913 23         16       204        50920
# 11914 26         17        61        28995

# %%
library(tidyverse)
advancedcars <- na.omit(cars)
advcars <- advancedcars[sample(1:nrow(advancedcars),10000),]
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
# -- Attaching packages --------------------------------------- tidyverse 1.2.1 --
# v ggplot2 3.1.1       v purrr   0.3.2
# v tibble  2.1.1       v dplyr   0.8.0.1
# v tidyr   0.8.3       v stringr 1.4.0
# v readr   1.3.1       v forcats 0.4.0
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()

# %%
#the higher the MPG the smaller the HP , inverse relation
ggplot(data= advcars) + geom_smooth(mapping = aes(x=HP,y=highwayMPG),color="brown")
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title

# %%
#the price increases every year 
ggplot(data= advcars) + geom_smooth(mapping = aes(x=Year,y=MSRP))
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title

# %%
ggplot(data= advcars) + geom_smooth(mapping = aes(x=Year,y=MSRP ,linetype=Driven_Wheels))
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title

# %%
ggplot(data= advcars) + geom_smooth(mapping = aes(x=Year,y=MSRP ,group=Driven_Wheels))
ggplot(data= advcars) + geom_smooth(mapping = aes(x=Year,y=MSRP ,color=Driven_Wheels),show.legend = FALSE) #false
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title
# plot without title

# %%
ggplot(data= advcars) + geom_point(mapping = aes(x=HP,y=citympg,size=Cylinders))
ggplot(data= advcars) + geom_point(mapping = aes(x=HP,y=highwayMPG,color=FuelType))
# Out:
# plot without title
# plot without title

# %%
ggplot(data= advcars) + geom_point(mapping = aes(x=HP,y=highwayMPG,alpha=Cylinders))
ggplot(data= advcars) + geom_point(mapping = aes(x=HP,y=highwayMPG))+facet_grid(Cylinders~ Driven_Wheels)
# Out:
# plot without title
# plot without title

# %%
ggplot(data= advcars) + geom_point(mapping = aes(x=HP,y=highwayMPG))+facet_grid(Cylinders~FuelType)
ggplot(data= advcars) + geom_point(mapping = aes(x=HP,y=highwayMPG))+facet_grid(.~Cylinders)
# Out:
# plot without title
# plot without title

# %%
ggplot(data= advcars) + geom_point(mapping = aes(x=Popularity,y=MSRP))+facet_wrap(~VehicleStyle,nrow=4)
ggplot(data= advcars) + geom_point(mapping = aes(x=Popularity,y=MSRP, color=NumberofDoors==2))
ggplot(data= advcars) + geom_point(mapping = aes(x=Popularity,y=MSRP, shape=TransmissionType))
# Out:
# plot without title
# plot without title
# plot without title

# %%
# adding random noise
ggplot(data= advcars) + geom_point(
  mapping = aes(x=HP,y=highwayMPG),
  position = "jitter"
)
# Out:
# plot without title

# %%
ggplot(data= advcars) + geom_bar(mapping = aes(x=Driven_Wheels,fill=FuelType)) 
ggplot(data= advcars) + geom_bar(mapping = aes(x=TransmissionType,fill=Make)) 
ggplot(data= advcars) + geom_bar(mapping = aes(x=MarketCategory,y=..prop..,fill=Make)) 
ggplot(data= advcars, mapping = aes(x=Driven_Wheels,fill=FuelType))+geom_bar(alpha=1/5,position = "identity") 
ggplot(data= advcars) + geom_bar(mapping = aes(x=Driven_Wheels,fill=FuelType),position = "dodge")
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %%
ggplot(data= advcars) + geom_histogram(mapping = aes(x=Popularity,fill=VehicleSize),binwidth = 1000) 
ggplot(data= advcars) + geom_histogram(mapping = aes(x=Popularity,fill=Driven_Wheels),binwidth = 500) 
ggplot(data= advcars) + geom_histogram(mapping = aes(x=MSRP,fill=Driven_Wheels),binwidth = 30000)
# Out:
# plot without title
# plot without title
# plot without title

# %%
#bar chart and a Coxcomb
bar <- ggplot(data= advcars) + geom_bar(mapping = aes(x=VehicleStyle,fill=VehicleStyle),
                                        show.legend = FALSE,
                                        width = 1
                                        ) + theme(aspect.ratio = 1) + labs(x = NULL, y = NULL)
bar + coord_flip()
bar + coord_polar()
# Out:
# plot without title
# plot without title

# %%
ggplot(data = advcars) +
  stat_summary(
    mapping = aes(x=highwayMPG, y=FuelType),
    fun.ymin = min,
    fun.ymax = max, 
    fun.y = median
)
# Out:
# plot without title

# %%
#< multiple geoms
ggplot(data= advcars,mapping = aes(x=HP,y=highwayMPG))+geom_smooth()+ geom_point()
ggplot(data= advcars,mapping = aes(x=HP,y=highwayMPG))+geom_smooth(data=filter(advcars,FuelType=="electric"))+ geom_point(mapping=aes(color=FuelType))
ggplot(data= advcars,mapping = aes(x=HP,y=highwayMPG))+geom_smooth(data=filter(advcars,FuelType=="natural gas"))+ geom_point(mapping=aes(color=FuelType))
ggplot(data= advcars,mapping = aes(x=HP,y=highwayMPG))+geom_smooth(data=filter(advcars,FuelType=="electric"))+ geom_point(mapping=aes(color=FuelType))
#<the outlair caused by electric fuel type
ggplot(data= advcars,mapping = aes(x=HP,y=highwayMPG))+geom_smooth(data=filter(advcars,Cylinders=="0"),se=FALSE)+ geom_point(mapping=aes(color=Cylinders))
#<the outlair caused by zero cylinders
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# "pseudoinverse used at 139.82"Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# "neighborhood radius 30.185"Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# "reciprocal condition number  0"Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# "There are other near singularities as well. 1382.7"Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# "pseudoinverse used at 139.82"Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# "neighborhood radius 30.185"Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# "reciprocal condition number  0"Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# "There are other near singularities as well. 1382.7"
# plot without title
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# "pseudoinverse used at 139.82"Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# "neighborhood radius 30.185"Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# "reciprocal condition number  0"Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# "There are other near singularities as well. 1382.7"Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# "pseudoinverse used at 139.82"Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# "neighborhood radius 30.185"Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# "reciprocal condition number  0"Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# "There are other near singularities as well. 1382.7"
# plot without title
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# "pseudoinverse used at 139.82"Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# "neighborhood radius 30.185"Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# "reciprocal condition number  0"Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# "There are other near singularities as well. 1382.7"
# plot without title
# plot without title
